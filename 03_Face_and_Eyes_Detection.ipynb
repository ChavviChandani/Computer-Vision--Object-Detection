# %% [markdown]
# ### Import Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Create Classifiers

# %%
face_classifier = cv2.CascadeClassifier('Haarcascades/haarcascade_frontalface_default.xml')
eye_classifier = cv2.CascadeClassifier('Haarcascades/haarcascade_eye.xml')

# %% [markdown]
# ### Open Image

# %%
img = cv2.imread('Images/eye_face.jpg')

# %% [markdown]
# ### Fix Image

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %% [markdown]
# ### Face Classifier

# %%
faces = face_classifier.detectMultiScale(fix_img,1.3,5)

# %% [markdown]
# ### If No Face Detected

# %%
if face is ():
    print('No faces found')

# %% [markdown]
# ### It's a Kind of Magic

# %%
def detect_faces_eyes(fix_img):
    face_rects = face_classifier.detectMultiScale(fix_img)
    
    for(x,y,w,h) in face_rects:
        cv2.rectangle(fix_img, (x,y), (x+w,y+h) , (255,0,0), 7)
    
    eye_rects = eye_classifier.detectMultiScale(fix_img)
    
    for(xi,yi,wi,hi) in eye_rects:
        cv2.rectangle(fix_img,(xi,yi),(xi+wi,yi+hi),(0,0,255),5)
        
    return fix_img

# %%
result = detect_faces_eyes(fix_img)
plt.imshow(result)
